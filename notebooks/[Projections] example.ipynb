# %%
# %load_ext autoreload
# %autoreload 2

# %%
import polyphase
import numpy as np
import matplotlib.pyplot as plt

# %%
M = [406.193,5.99,1]
chi = [0.435,0.77,1.00]
M, chi = polyphase.get_sample_data(1)
f = lambda x : polyphase.flory_huggins(x, M, chi)
engine = polyphase.PHASE(f,100,3)
parametrizations = [[1,2],[1,3],[2,3]]
for p in parametrizations:
    engine.compute(correction=3, lower_hull_method='point_at_infinity', indices=p)
    engine.plot()
# Out:
# Computation took 6.09s
# Computation took 5.72s
# Computation took 5.75s
