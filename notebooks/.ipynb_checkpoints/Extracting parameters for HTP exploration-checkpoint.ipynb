# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import sys
if '../' not in sys.path:
    sys.path.insert(0,'../')

from chemdataextractor import Document

# %%
data_folder = '../expts/data/htpdata/'
solvent_solubilities = pd.read_csv(data_folder+'solventSolubility1.csv',header=None,names=['hydrogen','polar','dispersive'])
solvent_solubilities.head()
# Out:
#    hydrogen  polar  dispersive
# 0      15.5   10.4         7.0
# 1      15.3   18.0         6.1
# 2      15.8    3.3         6.1
# 3      15.9    5.9        13.9
# 4      18.4    0.0         2.0

# %%
import tabula

pdf_name = data_folder+'polb23153.pdf'
df = tabula.read_pdf(pdf_name, pages=5)
# Out:
# Got stderr: May 19, 2020 6:27:43 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for C2 (4) in font HGILGL+AdvP4C4E74
# May 19, 2020 6:27:46 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for C2 (4) in font HGILGL+AdvP4C4E74

# %%
refine_df = df[0].dropna(how='all',axis=1)
refine_df.columns = ['name', 'dispersive','polar','hydrogen','R0','RED (PC61BM)']
small_molecules = refine_df.loc[1:5]
polymers = refine_df.loc[7:10]

# %%
for param in ['dispersive','polar','hydrogen']:
    small_molecules[param] = small_molecules[param].apply(lambda x: float(x.split()[0]))
    polymers[param] = polymers[param].apply(lambda x: float(x))
small_molecules = small_molecules.reset_index()
polymers = polymers.reset_index()
# Out:
# /projects/academic/olgawodo/kiranvad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /projects/academic/olgawodo/kiranvad/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
small_molecules, polymers
# Out:
# (   index        name  dispersive  polar  hydrogen   R0 RED (PC61BM)
#  0      1      PC61BM       19.89   5.68      3.64  6.6         0.00
#  1      2      PC71BM       20.16   5.37      4.49  7.0         0.15
#  2      3  DPP(TBFu)2       19.33   4.78      6.26  5.1         0.59
#  3      4   F8-NODIPS       18.48   2.62      3.24  8.1         0.52
#  4      5  DPP(PhTT)2       19.64   3.54      6.12    –            –,
#     index      name  dispersive  polar  hydrogen   R0 RED (PC61BM)
#  0      7  MDMO-PPV       19.06   5.62      5.28  5.5         0.42
#  1      8   MEH-PPV       19.06   5.38      5.44  6.0         0.41
#  2      9      P3HT       18.56   2.88      3.19  3.6         1.08
#  3     10       PFO       18.55   2.80      4.51  4.1         0.98)

# %%
solubility = {'solvents':solvent_solubilities,'small molecules':small_molecules,'polymers':polymers }

# %%
import pickle

with open(data_folder + 'solubility.pkl', 'wb') as handle:
    pickle.dump(solubility, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(data_folder + 'solubility.pkl', 'rb') as handle:
    data = pickle.load(handle)

# %%
from numpy.linalg import norm
from scipy.constants import gas_constant

def compute_chi(iSol,jSol,Vs = 100):
    """
    Inputs:
        iSol, jSol :  solubility parameters as a list (units MPa^{1/2})
        Vs :  Solvent molar volume in cm^3 / mol
    
    Units:
        iSol, jSol : both in Pa^{1/2} (Mega)
        thus delta_i,j will be in Pa^{1/2} (Mega)
        Formula for X_ij  = 0.34 + V_solvent/(RT) * (delta_i - delta_j)^2
                                   (m^3/mol)/((J/mol*K )* K) * (MPa^{1/2})^2
    """
    delta_i = norm(iSol,ord=None)
    delta_j = norm(jSol,ord=None)
    
    constant = 4.184*(2.045**2)/(8.314)
    
    chi_ij = 0.34 + (constant)*(Vs/(gas_constant*300)*(delta_i - delta_j)**2)
        
    return chi_ij

# %%
import itertools
import pdb
axes = [np.arange(0,len(data['solvents'])),np.arange(0,len(data['small molecules'])),np.arange(0,len(data['polymers']))]
counter = 1
for point in itertools.product(*axes):
    s = data['solvents'].loc[point[0]].tolist()
    sm = data['small molecules'].loc[point[1]].tolist()[2:5]
    p = data['polymers'].loc[point[2]].tolist()[2:5]
    fname = '{}_{}_{}'.format(point[0],data['small molecules']['name'].loc[point[1]],\
                            data['polymers']['name'].loc[point[2]])
    
    chi = []
    for comb in itertools.combinations([s,sm,p],2):
        chi.append(compute_chi(comb[0],comb[1]))
    counter += 1
# Out:
# 1721

# %%
from solvers.cem import CEMLaplace
from solvers.helpers import flory_huggins
from solvers.utils import makegrid3d

# %config InlineBackend.figure_format = 'svg'
from matplotlib import rc
rc('text', usetex=True)
import seaborn as sns
import matplotlib.pyplot as plt

grid = np.asarray(makegrid3d(num=40))
M = [5,100,1] # M_p=100 , M_sm=5, M_s=1
CHI = np.array([[0,chi[0],chi[1]],[chi[0],0,chi[2]],[chi[1],chi[2],0]])
# chi is ordered as follows : chi_{s,sm}, chi_{s,p}, chi_{sm,p}
labels = [r'$\varphi_{sm}$',r'$\varphi_{p}$',r'$\varphi_{s}$']

gmix = lambda x: flory_huggins(x, M, CHI,beta=1e-4)
energy = []
for point in grid:
    energy.append(gmix(point))
    
cem = CEMLaplace(grid,gmix,energy=energy)
fig, ax = plt.subplots()
ax = cem.plot_binodal(ax,fig,labels=labels)
title = r'$\chi: $'+ ','.join('{:.2f}'.format(k) for k in chi )
ax.set_title(title,pad=20)
plt.axis('off')
plt.show()

# %%
print(r'$\chi$'+' '.join('{:.2f}'.format(k) for k in chi))
# Out:
# $\chi$0.35 0.34 0.34
