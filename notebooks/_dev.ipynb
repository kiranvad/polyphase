# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import polyphase as phase
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pdb

# %%
f = phase.polynomial_energy
engine = phase.PHASE(f,200,3)
engine.solve(use_parallel=True, verbose=True, lift_label=True)
# Out:
# 2020-11-06 18:21:15,635	INFO services.py:1166 -- View the Ray dashboard at http://127.0.0.1:8265
# Energy computed at 0.32s
# Using edge correction to energy landscape
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-db3d4a31edf8> in <module>
#       1 f = phase.polynomial_energy
#       2 engine = phase.PHASE(f,200,3)
# ----> 3 engine.solve(use_parallel=True, verbose=True, lift_label=True)
#
# /projects/academic/olgawodo/kiranvad/Projects/Spring2020/PhaseModelling/polyphase/core.py in solve(self, **kwargs)
#     220
#     221             if self.use_parallel:
# --> 222                 boundary_points = np.asarray(self._process_parallel(self.is_boundary_point, self.grid_ray), dtype=bool)
#     223             else:
#     224                 boundary_points= np.asarray([self.is_boundary_point(x) for x in self.grid.T])
#
# /projects/academic/olgawodo/kiranvad/Projects/Spring2020/PhaseModelling/polyphase/core.py in _process_parallel(self, f, iterator)
#     180                 return f_out, indx
#     181
# --> 182         remaining_result_ids  = [remote_func.remote(indx, f_args) for indx,f_args in enumerate(iterator)]
#     183         if self.verbose:
#     184             print('Total of {} remote functions for <{}>'.format(len(iterator), f.__name__))
#
# TypeError: 'ray._raylet.ObjectRef' object is not iterable

# %%
phase.plot_mpltern(engine.grid, engine.simplices, engine.num_comps)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
