# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import polyphase as phase
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pdb

# %%
f = phase.polynomial_energy
engine = phase.PHASE(f,400,3)
engine.compute(use_parallel=False, verbose=True, lift_label=True)
# Out:
# 3-dimensional grid generated at 1.81s
# Energy computed at 4.03s
# Making energy manifold a paraboloid with 2x padding of 59.30 maximum energy
# Energy is corrected at 16.80s
# Convexhull is computed at 16.92s
# Using 3.13E-03 as a threshold for Laplacian of a simplex
# Simplices are refined at 17.12s
# Total of 6681 simplices in the convex hull
# Simplices are labelled at 19.25s
# Labels are lifted at 59.38s
# Total 0/6681 coplanar simplices
# Computation took 61.05s

# %%
phase.plot_mpltern(engine.grid, engine.simplices, engine.num_comps)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
boundary_points = np.asarray([engine.is_boundary_point(x) for x in engine.grid.T])
no_boundary_grid = np.where(~boundary_points)[0]
point = engine.grid[:,np.random.choice(no_boundary_grid)]
print(point)
engine.get_phase_compositions(point)
# Out:
# [0.18181819 0.35353536 0.46464647]
# (array([0.35897436, 0.14102564, 0.5       ]),
#  array([[0.07070708, 0.85858586, 0.07070708],
#         [0.85858586, 0.07070708, 0.07070708],
#         [0.07070708, 0.07070708, 0.85858586]]),
#  3)

# %%
engine.get_kwargs()
# Out:
# {'flag_refine_simplices': True,
#  'flag_lift_label': True,
#  'use_weighted_delaunay': False,
#  'flag_remove_collinear': False,
#  'beta': 0.0,
#  'flag_make_energy_paraboloid': True,
#  'pad_energy': 2,
#  'flag_lift_purecomp_energy': False,
#  'threshold_type': 'uniform',
#  'thresh_scale': 1.25,
#  'lift_grid_size': 100,
#  'verbose': True}
